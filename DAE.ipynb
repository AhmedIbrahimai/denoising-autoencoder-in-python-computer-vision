# %%
import numpy as np
from keras.datasets import mnist

# %%
(X_train , _) ,(X_test, _) = mnist.load_data()
X_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# (60000, 28, 28)

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(2,10, figsize = (16, 4))

count = 0

for i in range(2):
    for j in range(10):
        axes[i,j].imshow(X_train[count], cmap = 'gray')
        count+=1

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# prepare source data
noise_factor = 0.1

X_train_noise = X_train + noise_factor * np.random.normal(loc = 0., scale = 1., size = X_train.shape)
X_test_noise = X_test + noise_factor * np.random.normal(loc = 0., scale = 1., size = X_test.shape)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
fig, axes = plt.subplots(2,10, figsize = (16,4))

count = 0
for i in range(2):
    for j in range(10):
        axes[i,j].imshow(X_train_noise[count], cmap = 'gray')
        count+=1

# %%
X_train = X_train.reshape(X_train.shape[0], 28 ,28, 1)
X_test = X_test.reshape(X_test.shape[0], 28,28,1)

X_train_noise = X_train_noise.reshape(X_train_noise.shape[0], 28 ,28, 1)
X_test_noise = X_test_noise.reshape(X_test_noise.shape[0], 28,28,1)

X_train.shape, X_train_noise.shape
# Out:
# ((60000, 28, 28, 1), (60000, 28, 28, 1))

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPool2D, Dense, UpSampling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint

import tensorflow as tf

# %%
# encoder
encoder_input = Input(shape = X_train.shape[1:])
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(encoder_input)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size = (2,2), padding = 'same')(x)
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
encoded = MaxPool2D(pool_size = (2,2), padding = 'same')(x)

# %%
# decoder
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(encoded)
x = BatchNormalization()(x)
x = UpSampling2D()(x)
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = UpSampling2D()(x)
decoded = Conv2D(1, (3,3), activation = 'sigmoid', padding = 'same')(x)

# %%
autoencoder = Model(encoder_input, decoded, name = 'Denoising_Model')
autoencoder.summary()
# Out:
# Model: "Denoising_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  batch_normalization (Batch  (None, 28, 28, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  batch_normalization_2 (Bat  (None, 7, 7, 32)          128
#  chNormalization)
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_3 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28865 (112.75 KB)
# Trainable params: 28609 (111.75 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
autoencoder.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %%
checkpoint = ModelCheckpoint("denoising_model.h5", save_best_only=True, save_weights_only=False, verbose = 1)
history = autoencoder.fit(X_train_noise, X_train, batch_size = 128, epochs = 50, callbacks = checkpoint, validation_split = 0.25, verbose = 2)
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.12665, saving model to denoising_model.h5
# 352/352 - 16s - loss: 0.1571 - val_loss: 0.1267 - 16s/epoch - 45ms/step
# Epoch 2/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.12665 to 0.07640, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0759 - val_loss: 0.0764 - 3s/epoch - 7ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 0.07640 to 0.07274, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0730 - val_loss: 0.0727 - 3s/epoch - 8ms/step
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.07274
# 352/352 - 3s - loss: 0.0718 - val_loss: 0.0754 - 3s/epoch - 9ms/step
# Epoch 5/50
#
# Epoch 5: val_loss improved from 0.07274 to 0.07097, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0709 - val_loss: 0.0710 - 3s/epoch - 8ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 0.07097 to 0.07045, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0701 - val_loss: 0.0704 - 3s/epoch - 8ms/step
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.07045
# 352/352 - 3s - loss: 0.0696 - val_loss: 0.0719 - 3s/epoch - 7ms/step
# Epoch 8/50
#
# Epoch 8: val_loss improved from 0.07045 to 0.06958, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0692 - val_loss: 0.0696 - 3s/epoch - 7ms/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.06958
# 352/352 - 3s - loss: 0.0691 - val_loss: 0.0723 - 3s/epoch - 9ms/step
# Epoch 10/50
#
# Epoch 10: val_loss improved from 0.06958 to 0.06952, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0686 - val_loss: 0.0695 - 3s/epoch - 9ms/step
# Epoch 11/50
#
# Epoch 11: val_loss improved from 0.06952 to 0.06858, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0684 - val_loss: 0.0686 - 3s/epoch - 7ms/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.06858
# 352/352 - 3s - loss: 0.0682 - val_loss: 0.0743 - 3s/epoch - 8ms/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.06858
# 352/352 - 3s - loss: 0.0681 - val_loss: 0.0693 - 3s/epoch - 8ms/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 0.06858 to 0.06822, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0678 - val_loss: 0.0682 - 3s/epoch - 10ms/step
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 0.06822
# 352/352 - 2s - loss: 0.0677 - val_loss: 0.0684 - 2s/epoch - 7ms/step
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.06822
# 352/352 - 3s - loss: 0.0675 - val_loss: 0.0687 - 3s/epoch - 7ms/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.06822
# 352/352 - 3s - loss: 0.0675 - val_loss: 0.0687 - 3s/epoch - 7ms/step
# Epoch 18/50
#
# Epoch 18: val_loss improved from 0.06822 to 0.06788, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0674 - val_loss: 0.0679 - 3s/epoch - 8ms/step
# Epoch 19/50
#
# Epoch 19: val_loss improved from 0.06788 to 0.06774, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0673 - val_loss: 0.0677 - 3s/epoch - 9ms/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.06774
# 352/352 - 3s - loss: 0.0672 - val_loss: 0.0681 - 3s/epoch - 8ms/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.06774
# 352/352 - 3s - loss: 0.0671 - val_loss: 0.0681 - 3s/epoch - 7ms/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.06774
# 352/352 - 3s - loss: 0.0672 - val_loss: 0.0681 - 3s/epoch - 8ms/step
# Epoch 23/50
#
# Epoch 23: val_loss improved from 0.06774 to 0.06756, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0670 - val_loss: 0.0676 - 3s/epoch - 9ms/step
# Epoch 24/50
#
# Epoch 24: val_loss improved from 0.06756 to 0.06735, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0669 - val_loss: 0.0674 - 3s/epoch - 9ms/step
# Epoch 25/50
#
# Epoch 25: val_loss improved from 0.06735 to 0.06730, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0668 - val_loss: 0.0673 - 3s/epoch - 7ms/step
# Epoch 26/50
#
# Epoch 26: val_loss improved from 0.06730 to 0.06722, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0668 - val_loss: 0.0672 - 3s/epoch - 8ms/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.06722
# 352/352 - 3s - loss: 0.0668 - val_loss: 0.0678 - 3s/epoch - 7ms/step
# Epoch 28/50
#
# Epoch 28: val_loss improved from 0.06722 to 0.06715, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0668 - val_loss: 0.0672 - 3s/epoch - 9ms/step
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.06715
# 352/352 - 3s - loss: 0.0667 - val_loss: 0.0674 - 3s/epoch - 9ms/step
# Epoch 30/50
#
# Epoch 30: val_loss improved from 0.06715 to 0.06700, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0666 - val_loss: 0.0670 - 3s/epoch - 8ms/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 0.06700
# 352/352 - 3s - loss: 0.0666 - val_loss: 0.0670 - 3s/epoch - 7ms/step
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 0.06700
# 352/352 - 3s - loss: 0.0667 - val_loss: 0.0683 - 3s/epoch - 7ms/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.06700
# 352/352 - 3s - loss: 0.0665 - val_loss: 0.0672 - 3s/epoch - 9ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.06700
# 352/352 - 3s - loss: 0.0665 - val_loss: 0.0672 - 3s/epoch - 7ms/step
# Epoch 35/50
#
# Epoch 35: val_loss improved from 0.06700 to 0.06697, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0665 - val_loss: 0.0670 - 3s/epoch - 7ms/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.06697
# 352/352 - 3s - loss: 0.0664 - val_loss: 0.0680 - 3s/epoch - 7ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.06697
# 352/352 - 3s - loss: 0.0664 - val_loss: 0.0687 - 3s/epoch - 8ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.06697
# 352/352 - 3s - loss: 0.0664 - val_loss: 0.0674 - 3s/epoch - 9ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.06697
# 352/352 - 3s - loss: 0.0663 - val_loss: 0.0676 - 3s/epoch - 9ms/step
# Epoch 40/50
#
# Epoch 40: val_loss improved from 0.06697 to 0.06696, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0663 - val_loss: 0.0670 - 3s/epoch - 8ms/step
# Epoch 41/50
#
# Epoch 41: val_loss improved from 0.06696 to 0.06680, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0663 - val_loss: 0.0668 - 3s/epoch - 7ms/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.06680
# 352/352 - 3s - loss: 0.0663 - val_loss: 0.0668 - 3s/epoch - 8ms/step
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.06680
# 352/352 - 3s - loss: 0.0662 - val_loss: 0.0668 - 3s/epoch - 9ms/step
# Epoch 44/50
#
# Epoch 44: val_loss improved from 0.06680 to 0.06663, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0662 - val_loss: 0.0666 - 3s/epoch - 7ms/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 0.06663
# 352/352 - 3s - loss: 0.0662 - val_loss: 0.0666 - 3s/epoch - 8ms/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.06663
# 352/352 - 3s - loss: 0.0662 - val_loss: 0.0671 - 3s/epoch - 8ms/step
# Epoch 47/50
#
# Epoch 47: val_loss improved from 0.06663 to 0.06659, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0666 - 3s/epoch - 8ms/step
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.06659
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0680 - 3s/epoch - 8ms/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 0.06659
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0667 - 3s/epoch - 7ms/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.06659
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0666 - 3s/epoch - 8ms/step

# %%
# load best performance model
from keras.models import load_model
autoencoder = load_model('denoising_model.h5')
autoencoder.summary()
# Out:
# Model: "Denoising_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  batch_normalization (Batch  (None, 28, 28, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  batch_normalization_2 (Bat  (None, 7, 7, 32)          128
#  chNormalization)
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_3 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28865 (112.75 KB)
# Trainable params: 28609 (111.75 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
def visualize_data(data, row, column):
    data = data.reshape(data.shape[0], 28,28)
    count = 0
    fig, axes = plt.subplots(row, column, figsize = (16,4))
    for i in range(row):
        for j in range(column):
            axes[i,j].imshow(data[count], cmap = 'gray')
            count+=1

# %%
visualize_data(X_test_noise[:20], 2,10)

# %%
pred = autoencoder.predict(X_test_noise[:20])
pred.shape
# Out:
# 1/1 [==============================] - 0s 312ms/step
# (20, 28, 28, 1)

# %%
visualize_data(pred, 2, 10)
